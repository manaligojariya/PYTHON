# %%
#1. Compute the minimum, 25th percentile, median, 75th, and maximum of ser. 


import pandas as pd

data = pd.DataFrame({
    'name': ['bansi', 'vishwa', 'manali', 'zalak', 'nisha'],
    'subjects': ['java', 'php', 'html/css', 'python', 'R'],
    'marks': [98, 90, 78, 91, 87],
    'age': [11, 23, 23, 21, 21]
})

df=pd.DataFrame(data)


# #minimum
# print(.min())
Minimum = df['marks'].min()

# 25th percentile
q1 = df['marks'].quantile(0.25)


# # Median (50th percentile)
Median = df['marks'].median()


# 75th percentile
q3 = df['marks'].quantile(0.75)


# Maximum
Maximum = df['marks'].max()

print("Minimum:", Minimum)
print("25th Percentile:", q1)
print("Median:", Median)
print("75th Percentile:", q3)
print("Maximum:", Maximum)
# Out:
# Minimum: 78
# 25th Percentile: 87.0
# Median: 90.0
# 75th Percentile: 91.0
# Maximum: 98

# %%
# 2. Creating A Pandas Data Frame and Using Sample Data Sets 
#using list method
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 35, 40, 45],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami']
}

custom_df = pd.DataFrame(data)
print(custom_df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston
# 4      Eva   45        Miami

# %%
# 3. Using NumPy, create a Pandas Data Frame with five rows and three columns. 


import pandas as pd
import numpy as np

# Create a NumPy array with random values of shape (5, 3)
data = np.random.rand(5, 3)

df = pd.DataFrame(data, columns=['A', 'B', 'C'])
print(df)
# Out:
#           A         B         C
# 0  0.472257  0.354143  0.990492
# 1  0.290042  0.176434  0.138883
# 2  0.507882  0.311949  0.948026
# 3  0.336497  0.741620  0.307904
# 4  0.277625  0.644102  0.153284

# %%
#4. For a Pandas Data Frame created from a NumPy array, what is the default behavior for the labels for the columns? For the rows? 

import pandas as pd
import numpy as np

# Create a NumPy array with random values of shape (5, 3)
data = np.random.rand(5, 3)

# Create a DataFrame from the NumPy array
df = pd.DataFrame(data)

# Display the DataFrame
print(df)


# Pandas will assign integer labels starting from 0 and increasing sequentially for each column
#Pandas will assign integer labels starting from 0 and increasing sequentially for each row.
# Out:
#           0         1         2
# 0  0.006150  0.458999  0.038257
# 1  0.694365  0.706269  0.713662
# 2  0.348702  0.150685  0.329853
# 3  0.561665  0.679076  0.262805
# 4  0.215365  0.173271  0.938355

# %%
#  5. take csv file contains at least 10,000 rows and 12 columns which numerical and text values according to that continue following steps. 

df=pd.read_excel("C:\\Users\\lenovo\\Desktop\\DATA SCIENCE\\EXCEL\\Split Data.xlsx")

# %%
#6. Write the code to show the number of rows and columns in data frame. 

df
# Out:
#                                 Unnamed: 0    Unnamed: 1 Unnamed: 2  \
# 0    Office Supplies Sales Data - Jul 2018           NaN        NaN
# 1                                      NaN           NaN        NaN
# 2                                     Date          Item      Pd Id
# 3                      2018-07-01 00:00:00       Printer      KL001
# 4                      2018-07-01 00:00:00   White Board      KL002
# ..                                     ...           ...        ...
# 439                    2018-07-31 00:00:00       Printer      KL001
# 440                    2018-07-31 00:00:00       Printer      KL001
# 441                    2018-07-31 00:00:00  Office Chair      KL003
# 442                    2018-07-31 00:00:00         Diary      KL004
# 443                    2018-07-31 00:00:00         Diary      KL004
#
#          Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0               NaN        NaN        NaN         NaN
# 1               NaN        NaN        NaN         NaN
# 2         Sales Rep   Quantity      Price  Commission
# 3       Laura Smith         10         80        0.08
# 4    Stacey Johnson         18         40        0.06
# ..              ...        ...        ...         ...
# 439      Mark Booth          9         80        0.03
# 440       John Wood          8         80        0.08
# 441  Stacey Johnson          8        230        0.01
# 442      Bob Martin         12         16        0.04
# 443  Stacey Johnson         18         16        0.04
#
# [444 rows x 7 columns]

# %%
#7. How might you show the first few rows of data frame?

print("First few rows of the DataFrame:")
print(df.head())
# Out:
# First few rows of the DataFrame:
#                               Unnamed: 0   Unnamed: 1 Unnamed: 2  \
# 0  Office Supplies Sales Data - Jul 2018          NaN        NaN
# 1                                    NaN          NaN        NaN
# 2                                   Date         Item      Pd Id
# 3                    2018-07-01 00:00:00      Printer      KL001
# 4                    2018-07-01 00:00:00  White Board      KL002
#
#        Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6
# 0             NaN        NaN        NaN         NaN
# 1             NaN        NaN        NaN         NaN
# 2       Sales Rep   Quantity      Price  Commission
# 3     Laura Smith         10         80        0.08
# 4  Stacey Johnson         18         40        0.06

# %%
#8. If you select a single column from the diamonds Data Frame, what will be the type of the return value?
single_column = df['Unnamed: 3']

print(type(single_column))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#9. Create a line plot using the x and y values provided below. Label the y-axis as “Y” and
#label the x-axis as “X”.
#x = [3, 4, 5, 6]
#y = [1.5, 2, 2.5, 3] 

import matplotlib.pyplot as plt

# Provided x and y values
x = [3, 4, 5, 6]
y = [1.5, 2, 2.5, 3]

# Create a line plot
plt.plot(x, y)

# Add labels to the axes
plt.xlabel('X')
plt.ylabel('Y')

# Show the plot
plt.show()

# %%
# 10. Create an array of numbers between 0 and 6 with increments of 0.3 and name its “x”.
# Then on the same plot, plot x, x², x³, and x⁴. For consistency, use the following style lines
# respectively, “ro”, “bs”, “g”, and “:”. Lastly, make sure that the x-axis covers 0 to 6, while
# the y-axis spans from 0 to 125. Do not worry if you are not familiar with the style lines —
# you will recognize them as soon as you see the plot


import numpy as np
import matplotlib.pyplot as plt

# Create array x
x = np.arange(0, 6.3, 0.3)

# Plot x, x^2, x^3, and x^4
plt.plot(x, x, 'ro', label='x')    # x
plt.plot(x, x**2, 'bs', label='x^2')    # x^2
plt.plot(x, x**3, 'g', label='x^3')    # x^3
plt.plot(x, x**4, ':', label='x^4')    # x^4

# Set x-axis and y-axis limits
plt.xlim(0, 6)
plt.ylim(0, 125)
# Add labels and legend
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# Show plot
plt.show()

# %%
# 11. Heights and initials of a group of individuals are provided below. Create a bar plot titled
#“Height Comparison” to compare the heights among this group.
#height = [179, 155, 191, 152, 188, 177]
#names = ['QA', 'WB', 'EC', 'RD', 'TE', 'YF'] 

import matplotlib.pyplot as plt

# Heights and initials
height = [179, 155, 191, 152, 188, 177]
names = ['QA', 'WB', 'EC', 'RD', 'TE', 'YF']

# Create bar plot
plt.bar(names, height)

# Title and labels
plt.title('Height Comparison')
plt.xlabel('Initials')
plt.ylabel('Height (cm)')

# Show plot
plt.show()

# %%
#12. Plot a histogram of x, where x consists of 100,000 randomly-selected points with a normal
#distribution (hint: you can use numpy.random.randn() to generate the random points). The
#histogram should have 10 bins. Look at how the histogram changes when we try 20 and 50 bins. 


import numpy as np
import matplotlib.pyplot as plt

# Generate random data with normal distribution
x = np.random.randn(100000)

# Plot histogram with 10 bins
plt.figure(figsize=(12, 4))
plt.subplot(1, 3, 1)
plt.hist(x, bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram with 10 Bins')

# Plot histogram with 20 bins
plt.subplot(1, 3, 2)
plt.hist(x, bins=20, color='salmon', edgecolor='black')
plt.title('Histogram with 20 Bins')

# Plot histogram with 50 bins
plt.subplot(1, 3, 3)
plt.hist(x, bins=50, color='lightgreen', edgecolor='black')
plt.title('Histogram with 50 Bins')

plt.tight_layout()
plt.show()
